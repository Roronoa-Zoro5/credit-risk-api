# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
to_process_data = pd.read_csv('cs-training.csv')
to_process_data.head()
# Out:
# Unnamed: 0                              75000.500000
# SeriousDlqin2yrs                            0.000000
# RevolvingUtilizationOfUnsecuredLines        0.154181
# age                                        52.000000
# NumberOfTime30-59DaysPastDueNotWorse        0.000000
# DebtRatio                                   0.366508
# MonthlyIncome                            5400.000000
# NumberOfOpenCreditLinesAndLoans             8.000000
# NumberOfTimes90DaysLate                     0.000000
# NumberRealEstateLoansOrLines                1.000000
# NumberOfTime60-89DaysPastDueNotWorse        0.000000
# NumberOfDependents                          0.000000
# dtype: float64

# %%
# Handling missing values by using Median Imputation !

to_process_data['MonthlyIncome'].fillna(to_process_data['MonthlyIncome'].median())
to_process_data['NumberOfDependents'].fillna(to_process_data['NumberOfDependents'].median())
# to_process_data.isnull().sum()
processed_data = to_process_data.copy()
processed_data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Handling missing values by using Median Imputation !
# ----> 3 to_process_data['MonthlyIncome'].fillna(to_process_data['MonthlyIncome'].median())
#       4 to_process_data['NumberOfDependents'].fillna(to_process_data['NumberOfDependents'].median())
#       5 # to_process_data.isnull().sum()
#
# NameError: name 'to_process_data' is not defined

# %%
## now splitting the data into features and target variable

x = processed_data.drop(columns=['SeriousDlqin2yrs', 'Unnamed: 0'])
y = processed_data['SeriousDlqin2yrs']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
feature_names = x_train.columns

# %%
# scaling the data

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)       # do not fit test data to avoid data leakage 
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120000, 10), (30000, 10), (120000,), (30000,))

# %%
plot.hist(y_train, bins=50, label='train')
plot.hist(y_test, bins=50, label='test')
plot.show()

# %%
x_train_scaled = pd.DataFrame(x_train, columns=feature_names)
x_test_scaled = pd.DataFrame(x_test, columns=feature_names)
y_train = pd.DataFrame(y_train, columns=['SeriousDlqin2yrs'])
y_test = pd.DataFrame(y_test, columns=['SeriousDlqin2yrs'])       # guess it worked !
print(type(x_train_scaled))
print(type(x_test_scaled))

x_train_scaled.to_csv('x_train_scaled.csv', index=False)
x_test_scaled.to_csv('x_test_scaled.csv', index=False)
y_train.to_csv('y_train.csv', index=False)
y_test.to_csv('y_test.csv', index=False)

x_train_scaled.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#    RevolvingUtilizationOfUnsecuredLines       age  \
# 0                             -0.022803 -1.576975
# 1                             -0.020393  0.184209
# 2                             -0.022803 -0.628645
# 3                             -0.021217 -0.831859
# 4                             -0.022803 -1.170548
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                             -0.100746  -0.180840      -0.151997
# 1                             -0.100746  -0.180416      -0.334990
# 2                             -0.100746  -0.180824      -0.164834
# 3                             -0.100746  -0.180815       0.187732
# 4                             -0.100746  -0.180777      -0.045659
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                        -0.672522                -0.063764
# 1                         0.493412                -0.063764
# 2                        -1.255488                -0.063764
# 3                        -1.255488                -0.063764
# 4                         0.687734                -0.063764
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 0                     -0.900750                             -0.057706
# 1                     -0.017611                             -0.057706
# 2                     -0.900750                             -0.057706
# 3                     -0.900750                             -0.057706
# 4                     -0.017611                             -0.057706
#
#    NumberOfDependents
# 0           -0.666180
# 1           -0.666180
# 2            2.944145
# 3            3.846727
# 4           -0.666180

# %%
test_data = pd.read_csv('cs-test.csv')


### let's fill missing values 
# fill_test_data = test_data.fillna(0, inplace=False)
# fill_test_data.isnull().sum()
# fill_test_data.head()

to_process_data = test_data.copy()
to_process_data['MonthlyIncome'].fillna(to_process_data['MonthlyIncome'].median(), inplace=True)
to_process_data['NumberOfDependents'].fillna(to_process_data['NumberOfDependents'].median(), inplace=True)
to_process_data['SeriousDlqin2yrs'].fillna(0, inplace=True)


# to_process_data.isnull().sum()

to_process_data = scaler.transform(to_process_data.drop(columns=['Unnamed: 0', 'SeriousDlqin2yrs']))
# to_process_data.head()
print(to_process_data.shape)

processed_test_data = pd.DataFrame(to_process_data, columns=feature_names)
processed_test_data.to_csv('processed_test_data.csv', index=False)
# Out:
# C:\Users\Saad\AppData\Local\Temp\ipykernel_31492\1753482515.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to_process_data['MonthlyIncome'].fillna(to_process_data['MonthlyIncome'].median(), inplace=True)
# C:\Users\Saad\AppData\Local\Temp\ipykernel_31492\1753482515.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to_process_data['NumberOfDependents'].fillna(to_process_data['NumberOfDependents'].median(), inplace=True)
# C:\Users\Saad\AppData\Local\Temp\ipykernel_31492\1753482515.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to_process_data['SeriousDlqin2yrs'].fillna(0, inplace=True)
# (101503, 10)
