# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns

# %%
eda_data = pd.read_csv('cs-training.csv')
eda_data.head()
eda_data.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
# Just checking Null values and data types info

# eda_data.shape
# eda_data.info()
# print(eda_data.isnull().sum())
# eda_data.sample(5)

eda_data['DebtRatio'].value_counts().sort_index(ascending=False)
# Out:
# DebtRatio  RevolvingUtilizationOfUnsecuredLines
# 329664.0   0.000000                                   1
# 326442.0   0.001782                                   1
# 307001.0   0.034290                                   1
# 220516.0   0.182640                                   1
# 168835.0   0.000000                                   1
#                                                    ...
# 0.0        0.000034                                   1
#            0.000029                                   1
#            0.000027                                   1
#            0.000015                                   1
#            0.000000                                1860
# Name: count, Length: 144484, dtype: int64

# %%
target_counts = eda_data['SeriousDlqin2yrs']
plot.hist(target_counts, bins=40)
plot.show()

# %%
sns.scatterplot(data=eda_data, x='NumberOfTime30-59DaysPastDueNotWorse', y='MonthlyIncome', hue='SeriousDlqin2yrs')

plot.show()

# %%
sns.scatterplot(x=eda_data['RevolvingUtilizationOfUnsecuredLines'], y=eda_data['DebtRatio'], hue=eda_data['SeriousDlqin2yrs'])
# Out:
# <Axes: xlabel='RevolvingUtilizationOfUnsecuredLines', ylabel='DebtRatio'>
